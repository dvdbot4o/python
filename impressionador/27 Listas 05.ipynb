# %% [markdown]
# # Algumas Funções Básicas de Lista
#
# ## Tamanho da Lista
#
# tamanho = len(lista)

# %%
produtos = ['apple tv', 'mac', 'iphone x', 'IPad', 'apple watch', 'mac book', 'airpods']

# %% [markdown]
# - Quantos produtos temos a venda?

# %%
print(f" temos cerca de {len(produtos)} produtos ")
# Out:
#  temos cerca de 7 produtos

# %% [markdown]
# ## Maior e Menor Valor
#
# maior = max(lista)
#
# menor = min(lista)

# %%
vendas = [1000, 1500, 15000, 270, 900, 100, 1200]

print(f" o valor mais caro custa cerca de {max(vendas)}")
# Out:
#  o valor mais caro custa cerca de 100

# %% [markdown]
# - Qual o item mais vendido?
# - Qual o item menos vendido?
