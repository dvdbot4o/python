# %%
# 1  Faça um programa que mostre a mensagem "Alo mundo" na tela:

print(" Alo mundo")

# %%
# 2 Faça um programa que peça um número e então mostre a mensagem "O número informado foi [número]"

n = int(input("Digite um número: "))
print(f" o numero informado é {n}")
# Out:
#  o numero informado é 1

# %%
"""Exercício 03
Faça um programa que peça dois números e imprima a soma:"""

n1 = float(input(" digite um numero 1 "))
n2 = float(input(" digite um numero 2 "))

print(f" a soma do numero {n1} mais {n2} é igual a {n1+n2}")
# Out:
#  a soma do numero 1.0 mais 2.0 é igual a 3.0

# %%
"""Exercício 04
Faça um programa que peça as 4 notas bimestrais e mostre a média."""

n1 =float(input(" Digite a primeira nota "))

n2 =float(input(" Digite a primeira nota "))

n3 =float(input(" Digite a primeira nota "))

n4 =float(input(" Digite a primeira nota "))

print(f" a sua media foi {(n1 + n2 + n3 + n4 )/4}")
# Out:
#  a sua media foi 2.0

# %%
"""Exercício 05
Faça um programa que converta metros para centímetros:"""

m = float(input(" Digite a medição em mtros qu deseja transformar para centimetros "))

print(f" a medição de metros para centimetros é de {m * 100} cm ")
# Out:
#  a medição de metros para centimetros é de 200.0 cm

# %%
"""Exercício 06
Faça um programa que peça o raio de um círculo, calcule e mostre sua área:"""

r = float(input(" digite o raio de um circulo ?"))

print(f" a área desse circulo é de { (r**2)*3.14}")

# %%
"""Exercício 07
Faça um programa que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário."""

q = float(input(" diga o medicção dos lados do quadrado "))

print(f" a área do quadrado é {q**2} ")

# %%
"""Exercício 08
Faça um programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês."""

valor  = float(input(" o quanto voce ganha por hora ? "))

hora = float(input(" quantas horas trabalhadas ? "))

print(f" o salário no mês é {hora * valor}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 """Exercício 08
#       2 Faça um programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês."""
# ----> 4 valor  = float(input(" o quanto voce ganha por hora ? "))
#       6 hora = float(input(" quantas horas trabalhadas ? "))
#
# ValueError: could not convert string to float: ''

# %%
"""Exercício 09
Faça um programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius."""

f = float(input(" digite a temperatura em graus Fahrenheit que desja tranformar para celsius"))

print(f" o valor em graus celsius é de {5 * ((f - 32) / 9)}")
# Out:
#  o valor em graus celsius é de -17.22222222222222

# %%
"""Exercício 10
Faça um programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit."""

c = float(input(" digite a temperatura em graus Fahrenheit que desja tranformar para celsius"))

print(f" o valor em graus Fahrenheit é de {(c * 9/5) + 32}")

# %%
"""Exercício 11
Faça um programa que peça 2 números inteiros e um número real. Calcule e mostre:

O produto do dobro do primeiro com metade do segundo .
A soma do triplo do primeiro com o terceiro.
O terceiro elevado ao cubo."""

n1 = int(input(" digite o  numero 1 "))
n2 = int(input(" digite o  numero 2 "))
n3 = float(input(" digite o numero 3 "))

print(f"""
o produto do dobro do primeiro com o segundo é {(n1**2) + n2/2}
a soma do triplo do primeiro com o terceiro é {(n1**3) + n3}
o terceiro elevado ao cubo é {n3**3}
"""
)

# %%
"""Exercício 12
Tendo como dados de entrada um arquivo em Gigabytes, construa um algoritmo que faça a conversão para Megabytes, usando a seguinte fórmula:"""

g = float(input(" digite a o tamanho do arquivo em GIGABYTES : "))

print(f" o tamanho real em megabytes é de {g * 1000} ")

# %%
"""Exercício 13
Tendo como dados de entrada um arquivo em Gigabytes, construa um algoritmo que faça a conversão para Megabytes e Kilobytes, usando as seguintes fórmulas:

Para Megabytes: Gigabytes * 1024
Para Kilobytes: Gigabytes * 1024 * 1024
Responda o tamanho do arquivo em Megabytes e o tamanho em Kilobytes."""

g = float(input(" digite a o tamanho do arquivo em GIGABYTES : "))

print(f"""
o tamanho real em megabytes é de {g * 1000} e em kilobytes é {(g * 1000 * 1000)}

""")

# %%
"""Exercício 14
João, um pescador, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de peixes maior que o estabelecido pelo regulamento
de pesca do estado de São Paulo (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes)
e calcule o excesso. Gravar na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas."""

kg = float(input(" quanto KG voce pegou ? "))

if kg >= 50:
  print(f" o senhor vai pagar de multa é {(kg - 50) * 4} ")
else:
  print(" o senhor nao vai pagar multa ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 6
#       1 """Exercício 14
#       2 João, um pescador, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de peixes maior que o estabelecido pelo regulamento
#       3 de pesca do estado de São Paulo (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes)
#       4 e calcule o excesso. Gravar na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas."""
# ----> 6 kg = float(input(" quanto KG voce pegou ? "))
#
# ValueError: could not convert string to float: ''

# %%
"""Exercício 15
Faça um programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês,
sabendo-se que são descontados 11% para o Imposto de Renda, 8% para o INSS e 5% para o sindicato, faça um programa que nos dê:

salário bruto.
quanto pagou ao INSS.
quanto pagou ao sindicato.
o salário líquido.
calcule os descontos e o salário líquido, conforme a tabela abaixo:"""

salario = float(input(" digite o seu SALARIO BRUTO ?  "))

print(f"""

INSS  : {salario * 0.08 }
SIND  : {salario * 0.05 }
I.REN : {salario * 0.11 }
LIQUI : {(salario) - salario * 0.24 }

""")
# Out:
# INSS  : 128.8
# SIND  : 80.5
# I.REN : 177.1
# LIQUI : 1223.6

# %%
"""Exercício 16
Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da
tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R$ 80,00. Informe ao usuário a quantidades
de latas de tinta a serem compradas e o pre"""

area = float(input("Digite o tamanho da área a ser pintada (m²): "))

litros = area / 3
latas = int(litros / 18)


if litros % 18 != 0:
    latas += 1

preco = latas * 80

print("Quantidade de latas:", latas)
print("Preço total: R$", preco)

# %%
"""Exercício 17
Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro
para cada 6 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R$ 80,00 ou em galões de 3,6 litros, que custam R$ 25,00.

Informe ao usuário as quantidades de tinta a serem compradas e os respectivos preços em 3 situações:
comprar apenas latas de 18 litros;
comprar apenas galões de 3,6 litros;
misturar latas e galões, de forma que o desperdício de tinta seja menor. Acrescente 10% de folga e sempre arredonde os valores para cima, isto é, considere latas cheias."""

area = float(input("Digite o tamanho da área a ser pintada (m²): "))


litros = area / 6


litros *= 1.1


latas = int(litros / 18)
if litros % 18 != 0:
    latas += 1
preco_latas = latas * 80


galoes = int(litros / 3.6)
if litros % 3.6 != 0:
    galoes += 1
preco_galoes = galoes * 25


latas_misto = int(litros / 18)
resto = litros - (latas_misto * 18)

galoes_misto = int(resto / 3.6)
if resto % 3.6 != 0:
    galoes_misto += 1

preco_misto = (latas_misto * 80) + (galoes_misto * 25)

print("Situação 1 - Apenas latas:")
print("  Latas:", latas, "Preço: R$", preco_latas)

print("Situação 2 - Apenas galões:")
print("  Galões:", galoes, "Preço: R$", preco_galoes)

print("Situação 3 - Mistura:")
print("  Latas:", latas_misto, "Galões:", galoes_misto, "Preço: R$", preco_misto)

# %%
"""Exercício 18
Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps),
calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos)."""


mb = float(input(" digite o tamanho do arquivo em MB "))

mbps = float(input(" digite a velocidade da sua internet "))

print(f" vai demorar cerca de {mb/mbps} minutos ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       1 """Exercício 18
#       2 Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps),
#       3 calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos)."""
# ----> 6 mb = float(input(" digite o tamanho do arquivo em MB "))
#
# ValueError: could not convert string to float: ''
