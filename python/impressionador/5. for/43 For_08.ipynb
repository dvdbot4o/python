# %% [markdown]
# # For dentro de For
#
# Quando temos listas dentro de listas, às vezes precisamos fazer um "for dentro de for"

# %% [raw]
# for item in lista:
#     for item2 in lista2:
#         codigo aqui

# %% [markdown]
# Vamos pegar um exemplo de nível mínimo de estoque. Em uma fábrica você tem vários produtos e não pode deixar que os produtos fiquem em falta. Para isso, foi definido uma quantidade mínima de estoque que os produtos precisam ter:
#
# Identifique quais fábricas tem algum produto abaixo do nível de estoque
#
# - Agora ao invés de analisar o estoque de apenas 1 fábrica, vamos analisar o estoque de várias fábricas

# %% [raw]
# ✔ Com saída organizada
#
# estoque = [
#     [294, 125, 269, 208, 783, 852, 259, 371, 47, 102, 386, 87, 685, 686, 697, 941, 163, 631, 7, 714, 218, 670, 453],
#     [648, 816, 310, 555, 992, 643, 226, 319, 501, 23, 239, 42, 372, 441, 126, 645, 927, 911, 761, 445, 974, 2, 549],
#     [832, 683, 784, 449, 977, 705, 198, 937, 729, 327, 339, 10, 975, 310, 95, 689, 137, 795, 211, 538, 933, 751, 522],
#     [837, 168, 570, 397, 53, 297, 966, 714, 72, 737, 259, 629, 625, 469, 922, 305, 782, 243, 841, 848, 372, 621, 362],
#     [429, 242, 53, 985, 406, 186, 198, 50, 501, 870, 781, 632, 781, 105, 644, 509, 401, 88, 961, 765, 422, 340, 654],
# ]
#
# fabricas = [
#     'Lira Manufacturing',
#     'Fábrica Hashtag',
#     'Python Manufaturas',
#     'Produções e Cia',
#     'Manufatura e Cia'
# ]
#
# nivel_minimo = 50
#
# # Percorre estoque e fábrica ao mesmo tempo
# for fabrica, estoque_fabrica in zip(fabricas, estoque):
#
#     print(f"\nVerificando estoque da fábrica: {fabrica}")
#
#     for qtd in estoque_fabrica:
#         if qtd < nivel_minimo:
#             print(f"⚠ Produto com estoque baixo: {qtd}")

# %%
estoque = [
    [294, 125, 269, 208, 783, 852, 259, 371, 47, 102, 386, 87, 685, 686, 697, 941, 163, 631, 7, 714, 218, 670, 453],
    [648, 816, 310, 555, 992, 643, 226, 319, 501, 23, 239, 42, 372, 441, 126, 645, 927, 911, 761, 445, 974, 2, 549],
    [832, 683, 784, 449, 977, 705, 198, 937, 729, 327, 339, 10, 975, 310, 95, 689, 137, 795, 211, 538, 933, 751, 522],
    [837, 168, 570, 397, 53, 297, 966, 714, 72, 737, 259, 629, 625, 469, 922, 305, 782, 243, 841, 848, 372, 621, 362],
    [429, 242, 53, 985, 406, 186, 198, 50, 501, 870, 781, 632, 781, 105, 644, 509, 401, 88, 961, 765, 422, 340, 654],
]
fabricas = [
    'Lira Manufacturing', 
    'Fábrica Hashtag', 
    'Python Manufaturas', 
    'Produções e Cia', 
    'Manufatura e Cia'
]

nivel_minimo = 50

for i , esto in enumerate(estoque):
    print(f" verificando o estoque da fabrica {fabricas[i]}")
    for qtd in esto:
        if qtd < nivel_minimo:
            print(f" essa fabrica ta operando com produtos no nivel minimo {qtd}")
        else:
            print(f" essa fabrica nao esta  operando com produtos no nivel minimo {qtd}")
# Out:
#  verificando o estoque da fabrica Lira Manufacturing
#  essa fabrica nao esta  operando com produtos no nivel minimo 294
#  essa fabrica nao esta  operando com produtos no nivel minimo 125
#  essa fabrica nao esta  operando com produtos no nivel minimo 269
#  essa fabrica nao esta  operando com produtos no nivel minimo 208
#  essa fabrica nao esta  operando com produtos no nivel minimo 783
#  essa fabrica nao esta  operando com produtos no nivel minimo 852
#  essa fabrica nao esta  operando com produtos no nivel minimo 259
#  essa fabrica nao esta  operando com produtos no nivel minimo 371
#  essa fabrica ta operando com produtos no nivel minimo 47
#  essa fabrica nao esta  operando com produtos no nivel minimo 102
#  essa fabrica nao esta  operando com produtos no nivel minimo 386
#  essa fabrica nao esta  operando com produtos no nivel minimo 87
#  essa fabrica nao esta  operando com produtos no nivel minimo 685
#  essa fabrica nao esta  operando com produtos no nivel minimo 686
#  essa fabrica nao esta  operando com produtos no nivel minimo 697
#  essa fabrica nao esta  operando com produtos no nivel minimo 941
#  essa fabrica nao esta  operando com produtos no nivel minimo 163
#  essa fabrica nao esta  operando com produtos no nivel minimo 631
#  essa fabrica ta operando com produtos no nivel minimo 7
#  essa fabrica nao esta  operando com produtos no nivel minimo 714
#  essa fabrica nao esta  operando com produtos no nivel minimo 218
#  essa fabrica nao esta  operando com produtos no nivel minimo 670
#  essa fabrica nao esta  operando com produtos no nivel minimo 453
#  verificando o estoque da fabrica Fábrica Hashtag
#  essa fabrica nao esta  operando com produtos no nivel minimo 648
#  essa fabrica nao esta  operando com produtos no nivel minimo 816
#  essa fabrica nao esta  operando com produtos no nivel minimo 310
#  essa fabrica nao esta  operando com produtos no nivel minimo 555
#  essa fabrica nao esta  operando com produtos no nivel minimo 992
#  essa fabrica nao esta  operando com produtos no nivel minimo 643
#  essa fabrica nao esta  operando com produtos no nivel minimo 226
#  essa fabrica nao esta  operando com produtos no nivel minimo 319
#  essa fabrica nao esta  operando com produtos no nivel minimo 501
#  essa fabrica ta operando com produtos no nivel minimo 23
#  essa fabrica nao esta  operando com produtos no nivel minimo 239
#  essa fabrica ta operando com produtos no nivel minimo 42
#  essa fabrica nao esta  operando com produtos no nivel minimo 372
#  essa fabrica nao esta  operando com produtos no nivel minimo 441
#  essa fabrica nao esta  operando com produtos no nivel minimo 126
#  essa fabrica nao esta  operando com produtos no nivel minimo 645
#  essa fabrica nao esta  operando com produtos no nivel minimo 927
#  essa fabrica nao esta  operando com produtos no nivel minimo 911
#  essa fabrica nao esta  operando com produtos no nivel minimo 761
#  essa fabrica nao esta  operando com produtos no nivel minimo 445
#  essa fabrica nao esta  operando com produtos no nivel minimo 974
#  essa fabrica ta operando com produtos no nivel minimo 2
#  essa fabrica nao esta  operando com produtos no nivel minimo 549
#  verificando o estoque da fabrica Python Manufaturas
#  essa fabrica nao esta  operando com produtos no nivel minimo 832
#  essa fabrica nao esta  operando com produtos no nivel minimo 683
#  essa fabrica nao esta  operando com produtos no nivel minimo 784
#  essa fabrica nao esta  operando com produtos no nivel minimo 449
#  essa fabrica nao esta  operando com produtos no nivel minimo 977
#  essa fabrica nao esta  operando com produtos no nivel minimo 705
#  essa fabrica nao esta  operando com produtos no nivel minimo 198
#  essa fabrica nao esta  operando com produtos no nivel minimo 937
#  essa fabrica nao esta  operando com produtos no nivel minimo 729
#  essa fabrica nao esta  operando com produtos no nivel minimo 327
#  essa fabrica nao esta  operando com produtos no nivel minimo 339
#  essa fabrica ta operando com produtos no nivel minimo 10
#  essa fabrica nao esta  operando com produtos no nivel minimo 975
#  essa fabrica nao esta  operando com produtos no nivel minimo 310
#  essa fabrica nao esta  operando com produtos no nivel minimo 95
#  essa fabrica nao esta  operando com produtos no nivel minimo 689
#  essa fabrica nao esta  operando com produtos no nivel minimo 137
#  essa fabrica nao esta  operando com produtos no nivel minimo 795
#  essa fabrica nao esta  operando com produtos no nivel minimo 211
#  essa fabrica nao esta  operando com produtos no nivel minimo 538
#  essa fabrica nao esta  operando com produtos no nivel minimo 933
#  essa fabrica nao esta  operando com produtos no nivel minimo 751
#  essa fabrica nao esta  operando com produtos no nivel minimo 522
#  verificando o estoque da fabrica Produções e Cia
#  essa fabrica nao esta  operando com produtos no nivel minimo 837
#  essa fabrica nao esta  operando com produtos no nivel minimo 168
#  essa fabrica nao esta  operando com produtos no nivel minimo 570
#  essa fabrica nao esta  operando com produtos no nivel minimo 397
#  essa fabrica nao esta  operando com produtos no nivel minimo 53
#  essa fabrica nao esta  operando com produtos no nivel minimo 297
#  essa fabrica nao esta  operando com produtos no nivel minimo 966
#  essa fabrica nao esta  operando com produtos no nivel minimo 714
#  essa fabrica nao esta  operando com produtos no nivel minimo 72
#  essa fabrica nao esta  operando com produtos no nivel minimo 737
#  essa fabrica nao esta  operando com produtos no nivel minimo 259
#  essa fabrica nao esta  operando com produtos no nivel minimo 629
#  essa fabrica nao esta  operando com produtos no nivel minimo 625
#  essa fabrica nao esta  operando com produtos no nivel minimo 469
#  essa fabrica nao esta  operando com produtos no nivel minimo 922
#  essa fabrica nao esta  operando com produtos no nivel minimo 305
#  essa fabrica nao esta  operando com produtos no nivel minimo 782
#  essa fabrica nao esta  operando com produtos no nivel minimo 243
#  essa fabrica nao esta  operando com produtos no nivel minimo 841
#  essa fabrica nao esta  operando com produtos no nivel minimo 848
#  essa fabrica nao esta  operando com produtos no nivel minimo 372
#  essa fabrica nao esta  operando com produtos no nivel minimo 621
#  essa fabrica nao esta  operando com produtos no nivel minimo 362
#  verificando o estoque da fabrica Manufatura e Cia
#  essa fabrica nao esta  operando com produtos no nivel minimo 429
#  essa fabrica nao esta  operando com produtos no nivel minimo 242
#  essa fabrica nao esta  operando com produtos no nivel minimo 53
#  essa fabrica nao esta  operando com produtos no nivel minimo 985
#  essa fabrica nao esta  operando com produtos no nivel minimo 406
#  essa fabrica nao esta  operando com produtos no nivel minimo 186
#  essa fabrica nao esta  operando com produtos no nivel minimo 198
#  essa fabrica nao esta  operando com produtos no nivel minimo 50
#  essa fabrica nao esta  operando com produtos no nivel minimo 501
#  essa fabrica nao esta  operando com produtos no nivel minimo 870
#  essa fabrica nao esta  operando com produtos no nivel minimo 781
#  essa fabrica nao esta  operando com produtos no nivel minimo 632
#  essa fabrica nao esta  operando com produtos no nivel minimo 781
#  essa fabrica nao esta  operando com produtos no nivel minimo 105
#  essa fabrica nao esta  operando com produtos no nivel minimo 644
#  essa fabrica nao esta  operando com produtos no nivel minimo 509
#  essa fabrica nao esta  operando com produtos no nivel minimo 401
#  essa fabrica nao esta  operando com produtos no nivel minimo 88
#  essa fabrica nao esta  operando com produtos no nivel minimo 961
#  essa fabrica nao esta  operando com produtos no nivel minimo 765
#  essa fabrica nao esta  operando com produtos no nivel minimo 422
#  essa fabrica nao esta  operando com produtos no nivel minimo 340
#  essa fabrica nao esta  operando com produtos no nivel minimo 654
# O Kernel deu pane ao executar o código na célula atual ou em uma célula anterior.
#
# Analise o código nas células para identificar uma possível causa da pane.
#
# Clique <a href='https://aka.ms/vscodeJupyterKernelCrash'>aqui</a> para obter mais informações.
#
# Consulte Jupyter <a href='command:jupyter.viewOutput'>log</a> para obter mais detalhes.
