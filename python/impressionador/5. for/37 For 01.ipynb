# %% [markdown]
# # Estrutura de Repetição: for
#
# ### Funcionamento:

# %% [raw]
# for i in range(n):
#     repetir código n vezes

# %% [markdown]
# - Imagine que você está construindo uma automação para enviar todo dia por e-mail um resumo da produção de uma fábrica. Construa um código que exiba a quantidade produzida de cada os produto nesse "e-mail"

# %%
produtos = ['coca', 'pepsi', 'guarana', 'sprite', 'fanta']
producao = [15000, 12000, 13000, 5000, 250]

for i, produto in enumerate(produtos):
    print(f" o produto {produto} teve cerca de {producao[i]} vendidas ")
# Out:
#  o produto coca teve cerca de 15000 vendidas
#  o produto pepsi teve cerca de 12000 vendidas
#  o produto guarana teve cerca de 13000 vendidas
#  o produto sprite teve cerca de 5000 vendidas
#  o produto fanta teve cerca de 250 vendidas
