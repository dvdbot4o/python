# %% [markdown]
# # Listas de Listas
#
# ### Estrutura:
#
# Cada item de uma lista pode ser qualquer tipo de variável. Inclusive, uma lista.
#
# Quando dentro de uma lista temos cada item como sendo uma outra lista, temos uma "nested list", ou seja, uma lista de listas.
#
# Todas as regras de lista e tudo que vimos até agora funciona exatamente igual, mas vamos ver como isso funciona na prática

# %%
vendedores = ['Lira', 'João', 'Diego', 'Alon']
produtos = ['ipad', 'iphone']
vendas = [
    [100, 200],
    [300, 500],
    [50, 1000],
    [900, 10],
]

# %% [markdown]
# - Quanto João vendeu de IPad?
# - Quanto Diego vendeu de IPhone
# - Qual o total de vendas de IPhone?

# %%
print(f"""
A quantidade {produtos[0]} vendiddos pelo {vendedores[1]} foi de {vendas[0][2]}
A quantidade {produtos[1]} vendiddos pelo {vendedores[2]} foi de {vendas[2][1]}
o total de {produtos[1]} vendidos foi de {vendas[0][1] + vendas[1][1] + vendas[2][1] + vendas[3][1]}

""")
# Out:
# A quantidade ipad vendiddos pelo João foi de 12
# A quantidade iphone vendiddos pelo Diego foi de 1000
# o total de iphone vendidos foi de 1560

# %% [markdown]
# - E se Lira na verdade fez apenas 50 vendas de IPhone, como eu modifico na minha lista o valor de vendas dele?

# %%
vendas[0][1] = 50

print(f"A quantidade {produtos[1]} vendiddos pelo {vendedores[0]} foi de {vendas[0][1]}")
# Out:
# A quantidade iphone vendiddos pelo Lira foi de 50

# %% [markdown]
# - E se agora eu tenho um novo produto 'mac', como eu adiciono as vendas em cada um dos vendedores?

# %%
produtos.append("mac")

mac = [12, 50, 15,29]

vendas[0].append(12) #vendas[0].append(12)
vendas[1].append(mac[1])
vendas[2].append(mac[2])
vendas[3].append(mac[3])
print(vendas)
# Out:
# [[100, 200, 12, 12], [300, 500, 50, 50], [50, 1000, 15, 15], [900, 10, 29, 29]]
